# %% [markdown]
# <a href="https://colab.research.google.com/github/JaydaBubel/lab-customer-analysis-round-1/blob/master/Week1_Lab3_JaydaB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1_ = pd.read_csv('/content/drive/MyDrive/Ironhack/lab-customer-analysis-round-JB-master/files_for_lab/csv_files/file1.csv')
df1_
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2_ = pd.read_csv('/content/drive/MyDrive/Ironhack/lab-customer-analysis-round-JB-master/files_for_lab/csv_files/file2.csv')
df2_
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3_ = pd.read_csv('/content/drive/MyDrive/Ironhack/lab-customer-analysis-round-JB-master/files_for_lab/csv_files/file3.csv')
df3_
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print("Shape of DataFrame:", df1_.shape)
# Out:
# Shape of DataFrame: (4008, 11)

# %%
df1_.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in df1_.columns]
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
df1_.columns = cols
df1_
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data = pd.concat([df1_, df2_, df3_], axis=1)
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df = pd.DataFrame(data)
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns
print("Numerical columns:", numerical_cols)
print("Categorical columns:", categorical_cols)
# Out:
# Numerical columns: Index(['income', 'monthly_premium_auto', 'total_claim_amount', 'Income',
#        'Monthly Premium Auto', 'Total Claim Amount', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount'],
#       dtype='object')
# Categorical columns: Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'number_of_open_complaints', 'policy_type', 'vehicle_class', 'Customer',
#        'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Customer',
#        'State', 'Education', 'Gender', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df = pd.DataFrame(data)

# Delete the 'education' and 'number of open complaints' columns
df = data.drop(['education', 'number_of_open_complaints'], axis=1)
df
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065      NaN         NaN    NaN                     NaN      NaN
# 7066      NaN         NaN    NaN                     NaN      NaN
# 7067      NaN         NaN    NaN                     NaN      NaN
# 7068      NaN         NaN    NaN                     NaN      NaN
# 7069      NaN         NaN    NaN                     NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# ...

# %%
df['customer_lifetime_value'] = df['customer_lifetime_value'] * 100
df['customer_lifetime_value'] = df['customer_lifetime_value'].astype(float)
df
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+09      0.0
# 2     AI49188      Nevada      F             1.288743e+10  48767.0
# 3     WW63253  California      M             7.645862e+09      0.0
# 4     GA49547  Washington      M             5.363076e+09  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN         NaN    NaN                      NaN      NaN
# 7066      NaN         NaN    NaN                      NaN      NaN
# 7067      NaN         NaN    NaN                      NaN      NaN
# 7068      NaN         NaN    NaN                      NaN      NaN
# 7069      NaN         NaN    NaN                      NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+09      0.0
# 2     AI49188      Nevada      F             1.288743e+10  48767.0
# 3     WW63253  California      M             7.645862e+09      0.0
# 4     GA49547  Washington      M             5.363076e+09  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN         NaN    NaN                      NaN      NaN
# 7066      NaN         NaN    NaN                      NaN      NaN
# 7067      NaN         NaN    NaN                      NaN      NaN
# 7068      NaN         NaN    NaN                      NaN      NaN
# 7069      NaN         NaN    NaN                      NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df.drop_duplicates()
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+09      0.0
# 2     AI49188      Nevada      F             1.288743e+10  48767.0
# 3     WW63253  California      M             7.645862e+09      0.0
# 4     GA49547  Washington      M             5.363076e+09  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065      NaN         NaN    NaN                      NaN      NaN
# 7066      NaN         NaN    NaN                      NaN      NaN
# 7067      NaN         NaN    NaN                      NaN      NaN
# 7068      NaN         NaN    NaN                      NaN      NaN
# 7069      NaN         NaN    NaN                      NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
